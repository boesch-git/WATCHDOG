# %% [markdown]
# # Jupyter Notebook for WATCHDOG with ADR
#
# this Jupyter notebook is for documenting purposes of the code from WATCHDOG

# %%
print("this is a test oder heöllo world oder was auch immer 4711")
# Out:
# this is a test oder heöllo world oder was auch immer 4711
